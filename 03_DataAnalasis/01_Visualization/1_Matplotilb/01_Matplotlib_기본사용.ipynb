# %% [markdown]
# # Matplotlib란

# %% [markdown]
# * 파이썬 초창기부터 시각화 기능을 제공하였던 대표적인 파이썬 시각화 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 기본 그래프
#     * plot: 라인차트 지원
#     * 주로 시계열 데이터를 처리하기 유리 (연도별 매출, 시간대별 통행량 ...)

# %% [markdown]
# * plot([y좌표값]) : x좌표는 0부터 순차적으로 매핑

# %%
plt.plot([1,2,3,4]) # 좌표로 표시할 경우 (0,1), (1,2), (2,3), (3,4)
plt.show()

# %% [markdown]
# * plot( [x좌표값], [y좌표값]) # 각각의 x좌표수와 y좌표수의 갯수가 일치해야 한다.

# %%
# plt.plot( [1,2,3,4], [1,2,3,4] )
# plt.plot( [1,2,3,4], [1,4,9,16] )
plt.plot( [1,2,3,4], [10,4,9,16] )
plt.show()

# %% [markdown]
# # 스타일 지정

# %%
plt.plot( [1,2,3,4], [10,4,9,16], 'ro' ) # 세번째 인자: 스타일 관련 Format String
plt.show()

# %% [markdown]
# # 축의 범위 지정

# %% [markdown]
# * x축, y축의 최소 최대값은 차트에 입력하는 데이터의 최소, 최대값에 기인한다.
# * axis 함수로 축의 범위 지정 [xmin, xmax, ymin, ymax]

# %%
plt.plot( [1,2,3,4], [10,4,9,16], 'ro' ) # 세번째 인자: 스타일 관련 Format String
plt.axis([0,5,0,20])
plt.show()

# %% [markdown]
# # 여러 개의 그래프 그리기

# %%
import numpy as np
t = np.arange(0., 5., 0.2)
# 0에서 5사이 0.2씩 증가
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %% [markdown]
# * plot(그래프1,그래프2 ... , 그래프N)

# %%
plt.plot(t,t,'r--', 
         t, t**2, 'bs',
         t, t**3, 'g^')

# %% [markdown]
# # 기본색상 옵션

# %% [raw]
# 'r' - 빨간색
# 'b' - 파란색
# 'g' - 녹색
# 'c' - 청록색
# 'm' - 마젠타색
# 'y' - 노란색
# 'k' - 검은색
# 'w' - 흰색

# %% [markdown]
# # 데이터 변수 활용

# %%
data_x = [1,2,3,4,5]
data_y = [2,3,5,10,8]

# %%
plt.plot(data_x, data_y)
plt.show()

# %% [markdown]
# # 축 설정

# %% [markdown]
# ### 레이블 설정

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# x축 라벨
plt.xlabel('X-Label')
# y축 라벨
plt.ylabel('Y-Label')
plt.show()

# %% [markdown]
# * 여백설정

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# x축 레벨
plt.xlabel('X-Label', labelpad=15)
# y축 레벨
plt.ylabel('Y-Label', labelpad=15)
# plt.ylabel('Y-Label', labelpad=35)
plt.show()

# %% [markdown]
# * 폰트지정

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

plt.xlabel('X-Label', labelpad=15, fontdict=font1)

plt.ylabel('Y-Label', labelpad=15, fontdict=font2)
plt.show()

# %% [markdown]
# * 레이블 위치 설정

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
# plt.xlabel('X-Label', labelpad=15, fontdict=font1, loc='right')
plt.xlabel('X-Label', labelpad=15, fontdict=font1, loc='center')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
# plt.ylabel('Y-Label', labelpad=15, fontdict=font2, loc='top')
plt.ylabel('Y-Label', labelpad=15, fontdict=font2, loc='center')
plt.show()

# %% [markdown]
# * 범례 표시하기
#     * 범례: 차트에 표시되는 그래픽 요소를 구분하기 위한 레이블

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
# Step1] Label에 범례명을 입력한다.
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='Price ($)')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='Price (Won)')
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('X-Label', labelpad=15, fontdict=font1, loc='right')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('Y-Label', labelpad=15, fontdict=font2, loc='top')
# Step2] legend함수를 호출한다.
plt.legend()
plt.show()

# %% [markdown]
# * 범례 위치 지정

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
# Step1] Label에 범례명을 입력한다.
plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='Price ($)')
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('X-Label', labelpad=15, fontdict=font1, loc='right')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('Y-Label', labelpad=15, fontdict=font2, loc='top')
# Step2] legend함수를 호출한다.
# loc=(범례의 x비율, 범례의 y비율)
# 범례를 좌측 하단에 표시
# plt.legend( loc=(0.0,0.0)) 
# 전체 x의 50%, 전체 y의 50% 위치에 범례 표시
# plt.legend( loc=(0.5,0.5)) 
# plt.legend( loc=(1,1)) 
# lower/upper와 left/right의 조합으로 표현
# plt.legend(loc='lower right')

# loc옵션에 'best' 값을 지정하면 X,Y 좌표에 표시되는 차트요소를 고려해서 최적의 위치에 표시한다.
plt.legend(loc='best') 

plt.show()

# %% [markdown]
# * 범례의 열 개수 지정

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
# Step1] Label에 범례명을 입력한다.
plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='Price ($)')
# 여러개의 차트는 plot함수에서 추가로 정의하면 그릴 수 있다.
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('X-Label', labelpad=15, fontdict=font1, loc='right')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('Y-Label', labelpad=15, fontdict=font2, loc='top')
# Step2] legend함수를 호출한다.
# loc=(범례의 x비율, 범례의 y비율)
# 범례를 좌측 하단에 표시
# plt.legend( loc=(0.0,0.0)) 
# 전체 x의 50%, 전체 y의 50% 위치에 범례 표시
# plt.legend( loc=(0.5,0.5)) 
# plt.legend( loc=(1,1)) 
# lower/upper와 left/right의 조합으로 표현
# ncol: 컬럼수를 지정하여 컴럼수에 맞춰 범례표시
# plt.legend(loc='best', ncol=2)
# 홍길동 이순신 감감찬 유관순 홍범보
# ncol=3

# 홍길동 이순신 감감찬
# 유관순 홍범보
plt.legend(loc='best', ncol=1)

# loc옵션을 제외하면 X,Y 좌표에 표시되는 차트요소를 고려해서 최적의 위치에 표시한다.
# plt.legend( ) 

plt.show()

# %% [markdown]
# * 범례 폰트 크기 지정하기

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
# Step1] Label에 범례명을 입력한다.
plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='Dollar ($)')
# 여러개의 차트는 plot함수에서 추가로 정의하면 그릴 수 있다.
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('X-Label', labelpad=15, fontdict=font1, loc='right')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('Y-Label', labelpad=15, fontdict=font2, loc='top')
# Step2] legend함수를 호출한다.
# loc=(범례의 x비율, 범례의 y비율)
# 범례를 좌측 하단에 표시
# plt.legend( loc=(0.0,0.0)) 
# 전체 x의 50%, 전체 y의 50% 위치에 범례 표시
# plt.legend( loc=(0.5,0.5)) 
# plt.legend( loc=(1,1)) 
# lower/upper와 left/right의 조합으로 표현
# ncol: 컬럼수를 지정하여 컴럼수에 맞춰 범례표시
plt.legend(loc='best', ncol=2, fontsize=14)
# plt.legend(loc='best', ncol=2, fontsize=19)

# loc옵션을 제외하면 X,Y 좌표에 표시되는 차트요소를 고려해서 최적의 위치에 표시한다.
# plt.legend( ) 

plt.show()

# %% [markdown]
# * 한글 폰트 지정

# %%
from matplotlib import font_manager,rc
# 한글 폰트
font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

# %%
# Step1] Label에 범례명을 입력한다.
plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='가격 (원)')
# 여러개의 차트는 plot함수에서 추가로 정의하면 그릴 수 있다.
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='공급 (#)')
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('1사 분기', labelpad=15, loc='right')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('변동폭', labelpad=15, loc='top')
# Step2] legend함수를 호출한다.
# loc=(범례의 x비율, 범례의 y비율)
# 범례를 좌측 하단에 표시
# plt.legend( loc=(0.0,0.0)) 
# 전체 x의 50%, 전체 y의 50% 위치에 범례 표시
# plt.legend( loc=(0.5,0.5)) 
# plt.legend( loc=(1,1)) 
# lower/upper와 left/right의 조합으로 표현
# ncol: 컬럼수를 지정하여 컴럼수에 맞춰 범례표시
plt.legend(loc='best', ncol=2, fontsize=14)

# loc옵션을 제외하면 X,Y 좌표에 표시되는 차트요소를 고려해서 최적의 위치에 표시한다.
# plt.legend( ) 

plt.show()

# %% [markdown]
# * 범례 테두리

# %%
# Step1] Label에 범례명을 입력한다.
plt.plot([1, 2, 3, 4], [1, 4, 9, 16] , label='가격 (원)')
# 여러개의 차트는 plot함수에서 추가로 정의하면 그릴 수 있다.
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='공급 (#)')
# x축 레벨
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('1사 분기', labelpad=15, loc='right')
# y축 레벨
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('변동폭', labelpad=15, loc='top')
# Step2] legend함수를 호출한다.
# loc=(범례의 x비율, 범례의 y비율)
# 범례를 좌측 하단에 표시
# plt.legend( loc=(0.0,0.0)) 
# 전체 x의 50%, 전체 y의 50% 위치에 범례 표시
# plt.legend( loc=(0.5,0.5)) 
# plt.legend( loc=(1,1)) 
# lower/upper와 left/right의 조합으로 표현
# ncol: 컬럼수를 지정하여 컴럼수에 맞춰 범례표시
# frameon: 테두리 생성여부 (기본값이 True)
# shadow: 텍스트 상자에 그림자 여부
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
# plt.legend(loc='best', ncol=2, fontsize=14, frameon=True)

# loc옵션을 제외하면 X,Y 좌표에 표시되는 차트요소를 고려해서 최적의 위치에 표시한다.
# plt.legend( ) 

plt.show()

# %% [markdown]
# # 스케일 조정

# %%
plt.plot( [1,2,3,4], [2,5,7,10] )
plt.show()

# %%
plt.plot( [1,2,3,4], [2,5,7,10] )
plt.axis('scaled')
plt.show()

# %% [markdown]
# * 축의 범위 구하기

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

plt.axis('scaled')

plt.show()
# Out:
# (np.float64(0.85), np.float64(4.15)) (np.float64(1.6), np.float64(10.4))

# %% [markdown]
# # 선 종류

# %% [markdown]
# ### 기본유형

# %% [markdown]
# ![image.png](attachment:432ffe1e-bd07-4b65-8d45-f6be33e06cd8.png)

# %%
plt.plot([1, 2, 3], [4, 4, 4], '-', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %%
plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# * linestyle 속성으로 지정하기

# %% [markdown]
# ![image.png](attachment:7807a9fe-1308-400c-8302-518f4aa81c31.png)

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# * 선 끝 모양 지정하기

# %% [raw]
# solid_capstyle 속성에 지정

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
      solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')


plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.show()

# %% [markdown]
# * 튜플 사용하기

# %% [markdown]
# ![image.png](attachment:f6279391-a292-4c20-a0ce-6da5bd774046.png)

# %%
# linestyle=(0,[첫번째 닷의 길이, 첫번째 닷의 간격, 두번째 닷의 길이, 두번째 닷의 간격])
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 0)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='red', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='blue', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='green', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.show()

# %% [markdown]
# * 기타 속성

# %% [markdown]
# ![image.png](attachment:c877d793-1ef1-4d36-a87e-e5eaaae68c90.png)
